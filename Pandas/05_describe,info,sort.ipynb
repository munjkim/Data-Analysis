# %%
import pandas as pd

# %% [markdown]
# ### 기본 정보 알아보기

# %%
myfile = 'kpop_idols.csv'
df = pd.read_csv(myfile)

# %%
df
# Out:
#      Stage Name      Full Name Korean Name K. Stage Name Date of Birth  \
# 0           A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1           Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2          Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3          AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4          Ahra        Go Ahra         고아라            아라    2001-02-21
# ...         ...            ...         ...           ...           ...
# 1305        Ziu    Park Heejun         박희준            지우    1997-06-16
# 1306         ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1307        Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308       Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309       Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# ...

# %% [markdown]
# ### index, column, info

# %% [markdown]
# 1.1. column 출력하기

# %%
df.columns
# Out:
# Index(['Stage Name', 'Full Name', 'Korean Name', 'K. Stage Name',
#        'Date of Birth', 'Group', 'Country', 'Birthplace', 'Other Group',
#        'Gender'],
#       dtype='object')

# %% [markdown]
# 1.2. column 이름 재정의 하기

# %%
new_col = ['활동명', 'Full Name', 'Korean Name', 'K. Stage Name',
       'Date of Birth', 'Group', 'Country', 'Birthplace', 'Other Group',
       'Gender']
df.columns = new_col
df.columns
# Out:
# Index(['활동명', 'Full Name', 'Korean Name', 'K. Stage Name', 'Date of Birth',
#        'Group', 'Country', 'Birthplace', 'Other Group', 'Gender'],
#       dtype='object')

# %% [markdown]
# 2.1. index(행) 출력하기

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1310, step=1)

# %% [markdown]
# 2.2. info는 기본적인 행의 정보와 데이터 타입을 알려줌.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   활동명            1310 non-null   object
#  1   Full Name      1304 non-null   object
#  2   Korean Name    1304 non-null   object
#  3   K. Stage Name  1309 non-null   object
#  4   Date of Birth  1310 non-null   object
#  5   Group          1219 non-null   object
#  6   Country        1310 non-null   object
#  7   Birthplace     689 non-null    object
#  8   Other Group    122 non-null    object
#  9   Gender         1310 non-null   object
# dtypes: object(10)
# memory usage: 102.5+ KB

# %% [markdown]
# 3. 통계 정보 알아보기(describe)

# %%
df.describe()
# Out:
#           활동명    Full Name Korean Name K. Stage Name Date of Birth Group  \
# count    1310         1304        1304          1309          1310  1219
# unique   1135         1251        1241          1082          1181   208
# top     Jisoo  Lee Minhyuk         이서영            유진    2001-11-13   NCT
# freq        4            3           3             5             3    18
#
#             Country Birthplace     Other Group Gender
# count          1310        689             122   1310
# unique           12        135              55      2
# top     South Korea      Seoul  Super Junior-M      M
# freq           1204        188               6    676

# %% [markdown]
# 4. 형태 알아보기(shape)
#     - shape은 tuple로 반환되면, row x column 숫자로 반환

# %%
df.shape
# Out:
# (1310, 10)

# %% [markdown]
# 5. 상위 5개, 하위 5개만 보기

# %%
df.head()
# Out:
#     활동명      Full Name Korean Name K. Stage Name Date of Birth      Group  \
# 0   A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31  Limitless
# 1   Ace  Jang Wooyoung         장우영           에이스    1992-08-28        VAV
# 2  Aeji      Kwon Aeji         권애지            애지    1999-10-25    Hashtag
# 3  AhIn       Lee Ahin         이아인            아인    1999-09-27   MOMOLAND
# 4  Ahra        Go Ahra         고아라            아라    2001-02-21   Favorite
#
#        Country Birthplace Other Group Gender
# 0  South Korea        NaN         NaN      M
# 1  South Korea        NaN         NaN      M
# 2  South Korea      Daegu         NaN      F
# 3  South Korea      Wonju         NaN      F
# 4  South Korea      Yeosu         NaN      F

# %%
df.tail()
# Out:
#        활동명    Full Name Korean Name K. Stage Name Date of Birth         Group  \
# 1305   Ziu  Park Heejun         박희준            지우    1997-06-16           VAV
# 1306    ZN    Bae Jinye         배진예            지엔    1994-06-09        LABOUM
# 1307   Zoa   Cho Hyewon         조혜원            조아    2005-05-31       Weeekly
# 1308  Zuho     Bae Juho         백주호            주호    1996-07-04           SF9
# 1309  Zuny    Kim Joomi         김주미            주니    1994-12-08  Ladies' Code
#
#           Country Birthplace Other Group Gender
# 1305  South Korea        NaN         NaN      M
# 1306  South Korea    Bucheon       UNI.T      F
# 1307  South Korea        NaN         NaN      F
# 1308  South Korea        NaN         NaN      M
# 1309  South Korea    Gwangju         NaN      F

# %%
df.head(10)
# Out:
#        활동명      Full Name Korean Name K. Stage Name Date of Birth  \
# 0      A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1      Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2     Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3     AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4     Ahra        Go Ahra         고아라            아라    2001-02-21
# 5  Ahyoung    Cho Jayoung         조자영            아영    1991-05-26
# 6   Ahyung   Kang Ahyoung         강아형            아형    1996-08-27
# 7    Ailee      Lee Yejin         이예진           에일리    1989-05-30
# 8     Aini    Kim Heejung         김희정           아이니    1991-07-13
# 9    Aisha     Heo Yoorim         허유림            아샤    2000-07-21
#
#           Group      Country Birthplace Other Group Gender
# 0     Limitless  South Korea        NaN         NaN      M
# 1           VAV  South Korea        NaN         NaN      M
# 2       Hashtag  South Korea      Daegu         NaN      F
# ...

# %% [markdown]
# 6. 정렬하기

# %%
# 오름차순
df.sort_index()
# Out:
#        활동명      Full Name Korean Name K. Stage Name Date of Birth  \
# 0      A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
# 1      Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 2     Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 3     AhIn       Lee Ahin         이아인            아인    1999-09-27
# 4     Ahra        Go Ahra         고아라            아라    2001-02-21
# ...    ...            ...         ...           ...           ...
# 1305   Ziu    Park Heejun         박희준            지우    1997-06-16
# 1306    ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1307   Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1308  Zuho       Bae Juho         백주호            주호    1996-07-04
# 1309  Zuny      Kim Joomi         김주미            주니    1994-12-08
#
#              Group      Country Birthplace Other Group Gender
# 0        Limitless  South Korea        NaN         NaN      M
# ...

# %%
#내림차순
df.sort_index(ascending=False)
# Out:
#        활동명      Full Name Korean Name K. Stage Name Date of Birth  \
# 1309  Zuny      Kim Joomi         김주미            주니    1994-12-08
# 1308  Zuho       Bae Juho         백주호            주호    1996-07-04
# 1307   Zoa     Cho Hyewon         조혜원            조아    2005-05-31
# 1306    ZN      Bae Jinye         배진예            지엔    1994-06-09
# 1305   Ziu    Park Heejun         박희준            지우    1997-06-16
# ...    ...            ...         ...           ...           ...
# 4     Ahra        Go Ahra         고아라            아라    2001-02-21
# 3     AhIn       Lee Ahin         이아인            아인    1999-09-27
# 2     Aeji      Kwon Aeji         권애지            애지    1999-10-25
# 1      Ace  Jang Wooyoung         장우영           에이스    1992-08-28
# 0      A.M  Seong Hyunwoo         성현우           에이엠    1996-12-31
#
#              Group      Country Birthplace Other Group Gender
# 1309  Ladies' Code  South Korea    Gwangju         NaN      F
# ...

# %% [markdown]
# 7. Sort by Column

# %%
df.sort_values(by = 'Full Name')
# Out:
#           활동명     Full Name Korean Name K. Stage Name Date of Birth  \
# 313      Haru    Abe Haruno      아베 하루노            하루    2000-02-21
# 1297     Yuto   Adachi Yuto      아다치 유토            유토    1998-01-23
# 1201  Yeoreum  Ahn Chaeyeon         안채연            여름    1996-06-04
# 832      Niel    Ahn Daniel        안다니엘            니엘    1994-08-16
# 226    Eunjin    Ahn Eunjin         안은진            은진    1997-08-31
# ...       ...           ...         ...           ...           ...
# 442      Isol           NaN         NaN            이솔    1997-05-01
# 529    Jinhui           NaN         NaN            진희    1996-11-21
# 764      Mini           NaN         NaN            민이    2000-06-12
# 1212  Yeryung           NaN         NaN            예령    2002-06-22
# 1246   Yoonji           NaN         NaN            윤지    1998-07-21
#
#             Group      Country Birthplace Other Group Gender
# 313        NATURE        Japan        NaN         NaN      F
# ...

# %% [markdown]
# ascending = False 로 내림차순도 가능

# %% [markdown]
# ### 복수 정렬

# %%
df.sort_values(by = ['Full Name', 'Birthplace'])
# Out:
#           활동명     Full Name Korean Name K. Stage Name Date of Birth  \
# 313      Haru    Abe Haruno      아베 하루노            하루    2000-02-21
# 1297     Yuto   Adachi Yuto      아다치 유토            유토    1998-01-23
# 1201  Yeoreum  Ahn Chaeyeon         안채연            여름    1996-06-04
# 832      Niel    Ahn Daniel        안다니엘            니엘    1994-08-16
# 226    Eunjin    Ahn Eunjin         안은진            은진    1997-08-31
# ...       ...           ...         ...           ...           ...
# 529    Jinhui           NaN         NaN            진희    1996-11-21
# 310     Harin           NaN         NaN            하린    1995-11-21
# 442      Isol           NaN         NaN            이솔    1997-05-01
# 764      Mini           NaN         NaN            민이    2000-06-12
# 1246   Yoonji           NaN         NaN            윤지    1998-07-21
#
#             Group      Country Birthplace Other Group Gender
# 313        NATURE        Japan        NaN         NaN      F
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

result = [[1.811683, 1.765304, 1.728884, 1.743724, 1.722471, 1.764332, 1.692144, 1.738754, 1.728713, 1.738200],[1.019406, 0.987853, 0.992549, 1.008547, 0.994647, 1.015595, 0.984604, 0.984631, 1.019510, 1.032042]]
df = pd.DataFrame(result)
df = df.transpose()
df.columns = ['optimized', 'provided']

# %%
df.plot(y=['optimized', 'provided'], ylim=(0, 2), figsize=(10, 6), grid=True, ylabel="Speed-up rate", marker='o', ms=3)
# Out:
# <AxesSubplot:ylabel='Speed-up rate'>
